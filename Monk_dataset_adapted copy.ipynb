# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /opt/anaconda3/lib/python3.11/site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ucimlrepo) (2.2.1)
# Requirement already satisfied: certifi>=2020.12.5 in /opt/anaconda3/lib/python3.11/site-packages (from ucimlrepo) (2024.2.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from network import *

# %% [markdown]
# ## Import der Netzwerk-Komponenten
# Hier werden die Bausteine aus deinem minimalen `network`-Framework geladen:
# - `Dataset`, `DataLoader`: Datenhaltung und Mini-Batch-Erzeugung.
# - `Model`: Sequenzieller Container, der Layers verkettet.
# - `LinearLayer`, `ReLU`: Affine Schicht und Aktivierungsfunktion.
# - `MSELoss`: Mittlerer quadratischer Fehler für Training/Validierung.
# - `AdamWOptimizer`: Optimierer (Adam mit entkoppeltem Weight Decay).
#
# Diese Komponenten bilden die gesamte Trainings-/Validierungspipeline ohne externe Deep-Learning-Frameworks.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# MONK's Problems are 3 separate binary classification tasks (MONK-1/2/3)
# UCI also provides predefined TRAIN/TEST splits for each task (monks-*.train / monks-*.test).
# We'll use those files to avoid mixing the three tasks.

DATA_DIR = Path("monk+s+problems")  # folder in your repo
assert DATA_DIR.exists(), f"Could not find {DATA_DIR.resolve()}"

def load_monk(problem_id: int):
    """Load MONK-{problem_id} train/test, one-hot encode with aligned columns."""
    train_path = DATA_DIR / f"monks-{problem_id}.train"
    test_path  = DATA_DIR / f"monks-{problem_id}.test"
    assert train_path.exists() and test_path.exists(), "Missing train/test files."

    colnames = ["class", "a1", "a2", "a3", "a4", "a5", "a6", "id"]
    train_df = pd.read_csv(train_path, sep=r"\s+", header=None, names=colnames, engine="python")
    test_df  = pd.read_csv(test_path,  sep=r"\s+", header=None, names=colnames, engine="python")

    X_train_df = train_df[["a1","a2","a3","a4","a5","a6"]].astype("category")
    y_train_df = train_df[["class"]].astype(np.float32)

    X_test_df  = test_df[["a1","a2","a3","a4","a5","a6"]].astype("category")
    y_test_df  = test_df[["class"]].astype(np.float32)

    # One-hot encode; align test columns to train columns
    X_train_oh = pd.get_dummies(X_train_df)
    X_test_oh  = pd.get_dummies(X_test_df).reindex(columns=X_train_oh.columns, fill_value=0)

    X_train = X_train_oh.astype(np.float32).to_numpy()
    X_test  = X_test_oh.astype(np.float32).to_numpy()

    y_train = y_train_df.to_numpy().reshape(-1, 1)
    y_test  = y_test_df.to_numpy().reshape(-1, 1)

    return X_train, y_train, X_test, y_test, X_train_oh.columns.tolist()

# quick sanity check
for pid in [1,2,3]:
    Xt, yt, Xte, yte, cols = load_monk(pid)
    print(f"MONK-{pid}: X_train={Xt.shape}, y_train={yt.shape}, X_test={Xte.shape}, y_test={yte.shape}, input_dim={Xt.shape[1]}")
# Out:
# MONK-1: X_train=(124, 17), y_train=(124, 1), X_test=(432, 17), y_test=(432, 1), input_dim=17
# MONK-2: X_train=(169, 17), y_train=(169, 1), X_test=(432, 17), y_test=(432, 1), input_dim=17
# MONK-3: X_train=(122, 17), y_train=(122, 1), X_test=(432, 17), y_test=(432, 1), input_dim=17

# %% [markdown]
# ## Laden des MONK-Datensatzes
# Diese Zelle lädt das MONK-Datenset aus der UCI-Repository und zeigt Metadaten/Variablen.
# - `fetch_ucirepo(id=70)`: Lädt MONK's Problems.
# - `X`, `y`: Features und Targets als DataFrames.
# - Ausgabe: Metadaten und Variablenübersicht zur Orientierung.

# %%
# Choose which MONK problem to run (1, 2, or 3)
PROBLEM_ID = 2

X_train_full, y_train_full, X_test, y_test, feature_names = load_monk(PROBLEM_ID)

print("First 5 feature columns:", feature_names[:5])
print("Train class balance:", y_train_full.mean(), "(fraction of class=1)")
print("Test  class balance:", y_test.mean(), "(fraction of class=1)")

# Create a validation split from the TRAIN set (keep the official TEST set untouched)
rng = np.random.default_rng(42)
idx = np.arange(X_train_full.shape[0])
rng.shuffle(idx)

val_frac = 0.2
n_val = int(val_frac * len(idx))
val_idx, train_idx = idx[:n_val], idx[n_val:]

X_train, y_train = X_train_full[train_idx], y_train_full[train_idx]
X_val,   y_val   = X_train_full[val_idx],   y_train_full[val_idx]

print("X_train:", X_train.shape, "X_val:", X_val.shape, "X_test:", X_test.shape)
# Out:
# First 5 feature columns: ['a1_1', 'a1_2', 'a1_3', 'a2_1', 'a2_2']
# Train class balance: 0.37869823 (fraction of class=1)
# Test  class balance: 0.3287037 (fraction of class=1)
# X_train: (136, 17) X_val: (33, 17) X_test: (432, 17)

# %% [markdown]
# ## Erste Sichtung und Vorbereitung
# - Importiere Pandas/NumPy.
# - Lade `monk` erneut und weise `X_df`/`y_df` explizit zu.
# - Ausgabe: `head()`-Sichten zur Plausibilitätsprüfung der rohen Daten.

# %%
# --- Quick visualization ---
# MONK features are categorical; a common trick is: one-hot -> PCA(2D) -> scatter.
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def pca_scatter(X, y, title):
    pca = PCA(n_components=2, random_state=0)
    Z = pca.fit_transform(X)
    plt.figure(figsize=(6,5))
    plt.scatter(Z[:,0], Z[:,1], c=y.reshape(-1), s=20)
    plt.title(title)
    plt.xlabel("PC1")
    plt.ylabel("PC2")
    plt.show()

# class balance bar plot
plt.figure(figsize=(4,3))
vals, counts = np.unique(y_train_full.reshape(-1), return_counts=True)
plt.bar(vals.astype(int), counts)
plt.xticks([0,1], ["0","1"])
plt.title(f"MONK-{PROBLEM_ID}: class distribution (train)")
plt.show()

pca_scatter(X_train_full, y_train_full, f"MONK-{PROBLEM_ID}: PCA of one-hot features (train)")

# %% [markdown]
# ## One-Hot-Encoding und NumPy-Konvertierung
# - `pd.get_dummies(X_df)`: One-Hot-Encoding aller kategorialen Feature-Spalten (a1..a6).
# - Konvertiere Features zu `float32` NumPy-Array: `X`.
# - Targets: `y_df['class']` zu `float32` und als Spaltenvektor `(N, 1)` reshaped.
# - Ausgaben zeigen erwartete Shapes (typisch `(N, 17)` für X, `(N, 1)` für y).
# Hinweis: Einheitliche Datentypen und Shapes sind wichtig für die Mini-Batch-Verarbeitung.

# %%
# If you want to run all 3 problems in one go, set RUN_ALL=True.
RUN_ALL = False

# %% [markdown]
# ## Train/Val/Test-Split
# - Zerlege die Daten in 80% Training, 10% Validierung, 10% Test.
# - Behalte die Reihenfolge (kein Shuffle hier), da K-Fold später eigenes Shuffling nutzt.
# - Liefert `X_train`, `X_val`, `X_test` (und zugehörige `y_*`).
# Hinweis: Für reproduzierbare Vergleiche sind feste Splits hilfreich; K-Fold ergänzt später robuste Auswertung.

# %%
from network.dataset import Dataset
from network.dataloader import DataLoader

train_dataset = Dataset(X_train, y_train)
val_dataset   = Dataset(X_val,   y_val)
test_dataset  = Dataset(X_test,  y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=32, shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=32, shuffle=False)

# %% [markdown]
# ## DataLoader-Setup
# - Erzeuge `Dataset`-Objekte für die drei Splits.
# - Initialisiere `DataLoader` mit Batchgröße 32; Training mit Shuffle, Val/Test ohne Shuffle.
# - Zweck: Effiziente Mini-Batch-Verarbeitung und konsistente Evaluierung.

# %%
input_dim = X_train.shape[1]   # should be 17
print("input_dim:", input_dim)

model = Model(
    LinearLayer(input_dim, 8),
    ReLU(),
    LinearLayer(8, 8),
    ReLU(),
    LinearLayer(8, 1),
)

loss_fn = MSELoss()
optimizer = AdamWOptimizer(model, learning_rate=0.003, weight_decay=0.0)
# Out:
# input_dim: 17

# %% [markdown]
# ## Modellaufbau und Optimierer
# - Modell: `Linear(input_dim, 8) → ReLU → Linear(8, 16) → ReLU → Linear(16, 1)`.
# - Loss: `MSELoss` (voll reduziert).
# - Optimizer: `AdamWOptimizer` (`learning_rate=0.001`, `weight_decay=0.01`).
#
# Hinweise:
# - Die Ausgabe ist linear; für Klassifikations-Accuracy wird später ein dynamischer Threshold (Median der Predictions) verwendet.
# - Shapes müssen konsistent bleiben: z. B. `(Batch, 17) → ... → (Batch, 1)`.

# %%
num_epochs = 150
train_loss_history = []
val_loss_history   = []
val_acc_history    = []
val_thr_history    = []

for epoch in range(num_epochs):
    # ----- Training -----
    train_losses = []
    for x_batch, y_batch in train_loader:
        y_pred = model.forward(x_batch)
        loss = loss_fn.forward(y_pred, y_batch)

        grad = loss_fn.backward()
        model.backward(grad)
        optimizer.step()

        train_losses.append(loss)

    # ----- Validation -----
    val_losses = []
    preds_all = []
    ys_all = []

    for x_batch, y_batch in val_loader:
        y_pred = model.forward(x_batch)
        loss = loss_fn.forward(y_pred, y_batch)
        val_losses.append(loss)
        preds_all.append(y_pred)
        ys_all.append(y_batch)

    p = np.concatenate(preds_all, axis=0)
    y_true = np.concatenate(ys_all, axis=0)

    # Für lineare Outputs ist ein fixer Threshold 0.5 oft unpassend.
    # Median-Threshold ist robust gegen Skalierung/Shift der Scores pro Epoche.
    thr = float(np.median(p))
    preds = (p >= thr).astype(np.float32)
    val_acc = float((preds == y_true).sum() / y_true.size)

    mean_train = float(np.mean(train_losses))
    mean_val   = float(np.mean(val_losses))

    train_loss_history.append(mean_train)
    val_loss_history.append(mean_val)
    val_acc_history.append(val_acc)
    val_thr_history.append(thr)

    print(f"Epoch {epoch+1:03d} | "
          f"Train Loss: {mean_train:.4f} | "
          f"Val Loss: {mean_val:.4f} | "
          f"Val Acc: {val_acc:.4f} | "
          f"thr: {thr:.3f}")
# Out:
# Epoch 001 | Train Loss: 0.4721 | Val Loss: 0.2135 | Val Acc: 0.4545 | thr: 0.304
# Epoch 002 | Train Loss: 0.3356 | Val Loss: 0.2463 | Val Acc: 0.5758 | thr: 0.431
# Epoch 003 | Train Loss: 0.3357 | Val Loss: 0.2734 | Val Acc: 0.6364 | thr: 0.488
# Epoch 004 | Train Loss: 0.3026 | Val Loss: 0.2744 | Val Acc: 0.6364 | thr: 0.470
# Epoch 005 | Train Loss: 0.2637 | Val Loss: 0.2610 | Val Acc: 0.5758 | thr: 0.446
# Epoch 006 | Train Loss: 0.2450 | Val Loss: 0.2448 | Val Acc: 0.5758 | thr: 0.406
# Epoch 007 | Train Loss: 0.2536 | Val Loss: 0.2323 | Val Acc: 0.5758 | thr: 0.374
# Epoch 008 | Train Loss: 0.2231 | Val Loss: 0.2367 | Val Acc: 0.5758 | thr: 0.368
# Epoch 009 | Train Loss: 0.2214 | Val Loss: 0.2455 | Val Acc: 0.5758 | thr: 0.366
# Epoch 010 | Train Loss: 0.2145 | Val Loss: 0.2587 | Val Acc: 0.5758 | thr: 0.376
# Epoch 011 | Train Loss: 0.2077 | Val Loss: 0.2673 | Val Acc: 0.5758 | thr: 0.387
# Epoch 012 | Train Loss: 0.1928 | Val Loss: 0.2666 | Val Acc: 0.5152 | thr: 0.384
# Epoch 013 | Train Loss: 0.1897 | Val Loss: 0.2600 | Val Acc: 0.5152 | thr: 0.376
# Epoch 014 | Train Loss: 0.1774 | Val Loss: 0.2575 | Val Acc: 0.5152 | thr: 0.376
# Epoch 015 | Train Loss: 0.1899 | Val Loss: 0.2582 | Val Acc: 0.5152 | thr: 0.375
# Epoch 016 | Train Loss: 0.1696 | Val Loss: 0.2604 | Val Acc: 0.5152 | thr: 0.387
# Epoch 017 | Train Loss: 0.1824 | Val Loss: 0.2658 | Val Acc: 0.4545 | thr: 0.402
# Epoch 018 | Train Loss: 0.1747 | Val Loss: 0.2700 | Val Acc: 0.5152 | thr: 0.421
# Epoch 019 | Train Loss: 0.1797 | Val Loss: 0.2636 | Val Acc: 0.5152 | thr: 0.413
# Epoch 020 | Train Loss: 0.1650 | Val Loss: 0.2570 | Val Acc: 0.5152 | thr: 0.390
# Epoch 021 | Train Loss: 0.1617 | Val Loss: 0.2550 | Val Acc: 0.5152 | thr: 0.396
# Epoch 022 | Train Loss: 0.1697 | Val Loss: 0.2609 | Val Acc: 0.5152 | thr: 0.413
# Epoch 023 | Train Loss: 0.1667 | Val Loss: 0.2721 | Val Acc: 0.5152 | thr: 0.440
# Epoch 024 | Train Loss: 0.1620 | Val Loss: 0.2731 | Val Acc: 0.5152 | thr: 0.442
# Epoch 025 | Train Loss: 0.1513 | Val Loss: 0.2570 | Val Acc: 0.5152 | thr: 0.409
# Epoch 026 | Train Loss: 0.1478 | Val Loss: 0.2463 | Val Acc: 0.5152 | thr: 0.395
# Epoch 027 | Train Loss: 0.1400 | Val Loss: 0.2403 | Val Acc: 0.5152 | thr: 0.395
# Epoch 028 | Train Loss: 0.1573 | Val Loss: 0.2303 | Val Acc: 0.5152 | thr: 0.371
# Epoch 029 | Train Loss: 0.1443 | Val Loss: 0.2331 | Val Acc: 0.5152 | thr: 0.400
# Epoch 030 | Train Loss: 0.1426 | Val Loss: 0.2321 | Val Acc: 0.5758 | thr: 0.419
# Epoch 031 | Train Loss: 0.1357 | Val Loss: 0.2252 | Val Acc: 0.6364 | thr: 0.421
# Epoch 032 | Train Loss: 0.1332 | Val Loss: 0.2160 | Val Acc: 0.5758 | thr: 0.399
# Epoch 033 | Train Loss: 0.1351 | Val Loss: 0.2058 | Val Acc: 0.6364 | thr: 0.351
# Epoch 034 | Train Loss: 0.1476 | Val Loss: 0.2016 | Val Acc: 0.6364 | thr: 0.372
# Epoch 035 | Train Loss: 0.1263 | Val Loss: 0.1979 | Val Acc: 0.5758 | thr: 0.398
# Epoch 036 | Train Loss: 0.1306 | Val Loss: 0.1916 | Val Acc: 0.5758 | thr: 0.413
# Epoch 037 | Train Loss: 0.1298 | Val Loss: 0.1825 | Val Acc: 0.5758 | thr: 0.395
# Epoch 038 | Train Loss: 0.1191 | Val Loss: 0.1807 | Val Acc: 0.5758 | thr: 0.392
# Epoch 039 | Train Loss: 0.1105 | Val Loss: 0.1793 | Val Acc: 0.5758 | thr: 0.395
# Epoch 040 | Train Loss: 0.1176 | Val Loss: 0.1783 | Val Acc: 0.5758 | thr: 0.395
# Epoch 041 | Train Loss: 0.1045 | Val Loss: 0.1768 | Val Acc: 0.5758 | thr: 0.384
# Epoch 042 | Train Loss: 0.0991 | Val Loss: 0.1728 | Val Acc: 0.5758 | thr: 0.379
# Epoch 043 | Train Loss: 0.0981 | Val Loss: 0.1712 | Val Acc: 0.5758 | thr: 0.396
# Epoch 044 | Train Loss: 0.1060 | Val Loss: 0.1653 | Val Acc: 0.5758 | thr: 0.388
# Epoch 045 | Train Loss: 0.0918 | Val Loss: 0.1586 | Val Acc: 0.5758 | thr: 0.375
# Epoch 046 | Train Loss: 0.0911 | Val Loss: 0.1560 | Val Acc: 0.6364 | thr: 0.368
# Epoch 047 | Train Loss: 0.0890 | Val Loss: 0.1540 | Val Acc: 0.6364 | thr: 0.376
# Epoch 048 | Train Loss: 0.0876 | Val Loss: 0.1492 | Val Acc: 0.6364 | thr: 0.385
# Epoch 049 | Train Loss: 0.0839 | Val Loss: 0.1460 | Val Acc: 0.6364 | thr: 0.403
# Epoch 050 | Train Loss: 0.0955 | Val Loss: 0.1441 | Val Acc: 0.6364 | thr: 0.418
# Epoch 051 | Train Loss: 0.0790 | Val Loss: 0.1422 | Val Acc: 0.6364 | thr: 0.422
# Epoch 052 | Train Loss: 0.0785 | Val Loss: 0.1386 | Val Acc: 0.6364 | thr: 0.410
# Epoch 053 | Train Loss: 0.0869 | Val Loss: 0.1355 | Val Acc: 0.6364 | thr: 0.385
# Epoch 054 | Train Loss: 0.0877 | Val Loss: 0.1358 | Val Acc: 0.6364 | thr: 0.459
# Epoch 055 | Train Loss: 0.0842 | Val Loss: 0.1388 | Val Acc: 0.6364 | thr: 0.476
# Epoch 056 | Train Loss: 0.1006 | Val Loss: 0.1367 | Val Acc: 0.6364 | thr: 0.414
# Epoch 057 | Train Loss: 0.0812 | Val Loss: 0.1356 | Val Acc: 0.6364 | thr: 0.357
# Epoch 058 | Train Loss: 0.0781 | Val Loss: 0.1328 | Val Acc: 0.6364 | thr: 0.400
# Epoch 059 | Train Loss: 0.0748 | Val Loss: 0.1321 | Val Acc: 0.6364 | thr: 0.416
# Epoch 060 | Train Loss: 0.0841 | Val Loss: 0.1339 | Val Acc: 0.6364 | thr: 0.444
# Epoch 061 | Train Loss: 0.0748 | Val Loss: 0.1335 | Val Acc: 0.6364 | thr: 0.425
# Epoch 062 | Train Loss: 0.0675 | Val Loss: 0.1332 | Val Acc: 0.6364 | thr: 0.393
# Epoch 063 | Train Loss: 0.0716 | Val Loss: 0.1335 | Val Acc: 0.6364 | thr: 0.413
# Epoch 064 | Train Loss: 0.0679 | Val Loss: 0.1326 | Val Acc: 0.6364 | thr: 0.439
# Epoch 065 | Train Loss: 0.0747 | Val Loss: 0.1310 | Val Acc: 0.6364 | thr: 0.454
# Epoch 066 | Train Loss: 0.0672 | Val Loss: 0.1278 | Val Acc: 0.6364 | thr: 0.425
# Epoch 067 | Train Loss: 0.0625 | Val Loss: 0.1289 | Val Acc: 0.6364 | thr: 0.465
# Epoch 068 | Train Loss: 0.0628 | Val Loss: 0.1293 | Val Acc: 0.6364 | thr: 0.467
# Epoch 069 | Train Loss: 0.0714 | Val Loss: 0.1277 | Val Acc: 0.6364 | thr: 0.431
# Epoch 070 | Train Loss: 0.0592 | Val Loss: 0.1274 | Val Acc: 0.6364 | thr: 0.415
# Epoch 071 | Train Loss: 0.0769 | Val Loss: 0.1259 | Val Acc: 0.6364 | thr: 0.448
# Epoch 072 | Train Loss: 0.0602 | Val Loss: 0.1261 | Val Acc: 0.6364 | thr: 0.485
# Epoch 073 | Train Loss: 0.0577 | Val Loss: 0.1228 | Val Acc: 0.6970 | thr: 0.471
# Epoch 074 | Train Loss: 0.0627 | Val Loss: 0.1201 | Val Acc: 0.6364 | thr: 0.455
# Epoch 075 | Train Loss: 0.0603 | Val Loss: 0.1196 | Val Acc: 0.6364 | thr: 0.453
# Epoch 076 | Train Loss: 0.0617 | Val Loss: 0.1190 | Val Acc: 0.6364 | thr: 0.440
# Epoch 077 | Train Loss: 0.0627 | Val Loss: 0.1177 | Val Acc: 0.6364 | thr: 0.449
# Epoch 078 | Train Loss: 0.0559 | Val Loss: 0.1165 | Val Acc: 0.6970 | thr: 0.463
# Epoch 079 | Train Loss: 0.0600 | Val Loss: 0.1146 | Val Acc: 0.6970 | thr: 0.448
# Epoch 080 | Train Loss: 0.0569 | Val Loss: 0.1148 | Val Acc: 0.6970 | thr: 0.458
# Epoch 081 | Train Loss: 0.0583 | Val Loss: 0.1145 | Val Acc: 0.6970 | thr: 0.472
# Epoch 082 | Train Loss: 0.0619 | Val Loss: 0.1149 | Val Acc: 0.6970 | thr: 0.489
# Epoch 083 | Train Loss: 0.0579 | Val Loss: 0.1110 | Val Acc: 0.6970 | thr: 0.472
# Epoch 084 | Train Loss: 0.0547 | Val Loss: 0.1090 | Val Acc: 0.6364 | thr: 0.435
# Epoch 085 | Train Loss: 0.0565 | Val Loss: 0.1086 | Val Acc: 0.6364 | thr: 0.425
# Epoch 086 | Train Loss: 0.0595 | Val Loss: 0.1091 | Val Acc: 0.6970 | thr: 0.441
# Epoch 087 | Train Loss: 0.0554 | Val Loss: 0.1119 | Val Acc: 0.6970 | thr: 0.449
# Epoch 088 | Train Loss: 0.0450 | Val Loss: 0.1084 | Val Acc: 0.7576 | thr: 0.425
# Epoch 089 | Train Loss: 0.0471 | Val Loss: 0.1049 | Val Acc: 0.7576 | thr: 0.410
# Epoch 090 | Train Loss: 0.0498 | Val Loss: 0.1027 | Val Acc: 0.7576 | thr: 0.402
# Epoch 091 | Train Loss: 0.0454 | Val Loss: 0.1015 | Val Acc: 0.7576 | thr: 0.433
# Epoch 092 | Train Loss: 0.0590 | Val Loss: 0.1025 | Val Acc: 0.7576 | thr: 0.471
# Epoch 093 | Train Loss: 0.0517 | Val Loss: 0.1004 | Val Acc: 0.7576 | thr: 0.427
# Epoch 094 | Train Loss: 0.0438 | Val Loss: 0.1016 | Val Acc: 0.6970 | thr: 0.387
# Epoch 095 | Train Loss: 0.0497 | Val Loss: 0.1014 | Val Acc: 0.6970 | thr: 0.405
# Epoch 096 | Train Loss: 0.0456 | Val Loss: 0.1005 | Val Acc: 0.7576 | thr: 0.445
# Epoch 097 | Train Loss: 0.0439 | Val Loss: 0.0967 | Val Acc: 0.7576 | thr: 0.448
# Epoch 098 | Train Loss: 0.0438 | Val Loss: 0.0960 | Val Acc: 0.7576 | thr: 0.478
# Epoch 099 | Train Loss: 0.0428 | Val Loss: 0.0936 | Val Acc: 0.7576 | thr: 0.478
# Epoch 100 | Train Loss: 0.0464 | Val Loss: 0.0922 | Val Acc: 0.7576 | thr: 0.484
# Epoch 101 | Train Loss: 0.0426 | Val Loss: 0.0927 | Val Acc: 0.7576 | thr: 0.442
# Epoch 102 | Train Loss: 0.0388 | Val Loss: 0.0935 | Val Acc: 0.7576 | thr: 0.437
# Epoch 103 | Train Loss: 0.0396 | Val Loss: 0.0943 | Val Acc: 0.7576 | thr: 0.472
# Epoch 104 | Train Loss: 0.0375 | Val Loss: 0.0938 | Val Acc: 0.7576 | thr: 0.463
# Epoch 105 | Train Loss: 0.0398 | Val Loss: 0.0934 | Val Acc: 0.7576 | thr: 0.440
# Epoch 106 | Train Loss: 0.0406 | Val Loss: 0.0931 | Val Acc: 0.7576 | thr: 0.468
# Epoch 107 | Train Loss: 0.0401 | Val Loss: 0.0927 | Val Acc: 0.7576 | thr: 0.486
# Epoch 108 | Train Loss: 0.0381 | Val Loss: 0.0910 | Val Acc: 0.7576 | thr: 0.465
# Epoch 109 | Train Loss: 0.0393 | Val Loss: 0.0925 | Val Acc: 0.7576 | thr: 0.446
# Epoch 110 | Train Loss: 0.0356 | Val Loss: 0.0923 | Val Acc: 0.7576 | thr: 0.475
# Epoch 111 | Train Loss: 0.0399 | Val Loss: 0.0921 | Val Acc: 0.7576 | thr: 0.480
# Epoch 112 | Train Loss: 0.0335 | Val Loss: 0.0903 | Val Acc: 0.7576 | thr: 0.483
# Epoch 113 | Train Loss: 0.0401 | Val Loss: 0.0879 | Val Acc: 0.7576 | thr: 0.488
# Epoch 114 | Train Loss: 0.0332 | Val Loss: 0.0867 | Val Acc: 0.7576 | thr: 0.515
# Epoch 115 | Train Loss: 0.0385 | Val Loss: 0.0854 | Val Acc: 0.7576 | thr: 0.527
# Epoch 116 | Train Loss: 0.0344 | Val Loss: 0.0860 | Val Acc: 0.7576 | thr: 0.541
# Epoch 117 | Train Loss: 0.0354 | Val Loss: 0.0860 | Val Acc: 0.7576 | thr: 0.509
# Epoch 118 | Train Loss: 0.0391 | Val Loss: 0.0876 | Val Acc: 0.7576 | thr: 0.502
# Epoch 119 | Train Loss: 0.0380 | Val Loss: 0.0886 | Val Acc: 0.7576 | thr: 0.530
# Epoch 120 | Train Loss: 0.0354 | Val Loss: 0.0879 | Val Acc: 0.7576 | thr: 0.514
# Epoch 121 | Train Loss: 0.0303 | Val Loss: 0.0869 | Val Acc: 0.7576 | thr: 0.498
# Epoch 122 | Train Loss: 0.0352 | Val Loss: 0.0861 | Val Acc: 0.7576 | thr: 0.501
# Epoch 123 | Train Loss: 0.0383 | Val Loss: 0.0844 | Val Acc: 0.7576 | thr: 0.511
# Epoch 124 | Train Loss: 0.0345 | Val Loss: 0.0823 | Val Acc: 0.7576 | thr: 0.502
# Epoch 125 | Train Loss: 0.0344 | Val Loss: 0.0806 | Val Acc: 0.7576 | thr: 0.485
# Epoch 126 | Train Loss: 0.0293 | Val Loss: 0.0796 | Val Acc: 0.7576 | thr: 0.512
# Epoch 127 | Train Loss: 0.0331 | Val Loss: 0.0789 | Val Acc: 0.7576 | thr: 0.521
# Epoch 128 | Train Loss: 0.0346 | Val Loss: 0.0790 | Val Acc: 0.7576 | thr: 0.495
# Epoch 129 | Train Loss: 0.0373 | Val Loss: 0.0798 | Val Acc: 0.7576 | thr: 0.529
# Epoch 130 | Train Loss: 0.0283 | Val Loss: 0.0810 | Val Acc: 0.7576 | thr: 0.505
# Epoch 131 | Train Loss: 0.0288 | Val Loss: 0.0809 | Val Acc: 0.7576 | thr: 0.508
# Epoch 132 | Train Loss: 0.0283 | Val Loss: 0.0806 | Val Acc: 0.7576 | thr: 0.506
# Epoch 133 | Train Loss: 0.0287 | Val Loss: 0.0796 | Val Acc: 0.7576 | thr: 0.508
# Epoch 134 | Train Loss: 0.0332 | Val Loss: 0.0797 | Val Acc: 0.7576 | thr: 0.492
# Epoch 135 | Train Loss: 0.0271 | Val Loss: 0.0793 | Val Acc: 0.7576 | thr: 0.493
# Epoch 136 | Train Loss: 0.0292 | Val Loss: 0.0792 | Val Acc: 0.7576 | thr: 0.491
# Epoch 137 | Train Loss: 0.0329 | Val Loss: 0.0808 | Val Acc: 0.7576 | thr: 0.484
# Epoch 138 | Train Loss: 0.0289 | Val Loss: 0.0801 | Val Acc: 0.7576 | thr: 0.484
# Epoch 139 | Train Loss: 0.0295 | Val Loss: 0.0790 | Val Acc: 0.7576 | thr: 0.487
# Epoch 140 | Train Loss: 0.0274 | Val Loss: 0.0771 | Val Acc: 0.7576 | thr: 0.513
# Epoch 141 | Train Loss: 0.0235 | Val Loss: 0.0766 | Val Acc: 0.7576 | thr: 0.514
# Epoch 142 | Train Loss: 0.0240 | Val Loss: 0.0771 | Val Acc: 0.7576 | thr: 0.510
# Epoch 143 | Train Loss: 0.0261 | Val Loss: 0.0776 | Val Acc: 0.7576 | thr: 0.516
# Epoch 144 | Train Loss: 0.0249 | Val Loss: 0.0775 | Val Acc: 0.7576 | thr: 0.523
# Epoch 145 | Train Loss: 0.0289 | Val Loss: 0.0771 | Val Acc: 0.7576 | thr: 0.517
# Epoch 146 | Train Loss: 0.0259 | Val Loss: 0.0773 | Val Acc: 0.7576 | thr: 0.519
# Epoch 147 | Train Loss: 0.0234 | Val Loss: 0.0769 | Val Acc: 0.7576 | thr: 0.527
# Epoch 148 | Train Loss: 0.0260 | Val Loss: 0.0763 | Val Acc: 0.7576 | thr: 0.527
# Epoch 149 | Train Loss: 0.0235 | Val Loss: 0.0764 | Val Acc: 0.7576 | thr: 0.522
# Epoch 150 | Train Loss: 0.0242 | Val Loss: 0.0763 | Val Acc: 0.7576 | thr: 0.528

# %% [markdown]
# ## Training und Validierung pro Epoche
# Ablauf je Epoche:
# - Training: Vorwärtslauf → MSE-Loss → Backward (Loss-Gradient) → Parameter-Update (AdamW).
# - Validierung: Vorwärtslauf auf Val-Splits, Sammeln der Val-Losse.
# - Accuracy: Binarisierung der Vorhersagen mit Schwelle 0.5 (hier als einfache Heuristik) und Vergleich mit `y_batch`.
#
# Hinweise:
# - Mit linearer Ausgabe ist der feste Threshold 0.5 nicht immer optimal. In späteren Zellen wird ein Median-Threshold genutzt, der robuster gegenüber Skalenverschiebungen ist.
# - `train_loss_history`, `val_loss_history`, `val_acc_history` speichern die Metriken je Epoche für Plots.

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, len(train_loss_history) + 1)

plt.figure(figsize=(12, 5))

# ------------------ LOSS ------------------
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss_history, label="Train Loss")
plt.plot(epochs, val_loss_history, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Train & Validation Loss over Epochs")
plt.legend()
plt.grid(alpha=0.3)

# ------------------ ACCURACY ------------------
plt.subplot(1, 2, 2)
plt.plot(epochs, val_acc_history, label="Val Accuracy", color="green")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy over Epochs")
plt.ylim(0.0, 1.0)
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# ---- Final evaluation on the official TEST split ----
# Wir wählen einen Threshold auf dem Val-Split (einfach: Median der Val-Scores)
# und berichten damit die Test-Accuracy konsistent zur Trainingsevaluation.
import numpy as np

test_losses = []
preds_test_all = []
ys_test_all = []

for x_batch, y_batch in test_loader:
    y_pred = model.forward(x_batch)
    loss = loss_fn.forward(y_pred, y_batch)
    test_losses.append(loss)
    preds_test_all.append(y_pred)
    ys_test_all.append(y_batch)

p_test = np.concatenate(preds_test_all, axis=0)
y_test_all = np.concatenate(ys_test_all, axis=0)

# Threshold aus letzter Epoche (oder Median der aktuellen Val-Scores)
if 'val_thr_history' in globals() and len(val_thr_history) > 0:
    thr = float(val_thr_history[-1])
else:
    # Fallback: Median der Test-Scores (nicht ideal, aber definiert)
    thr = float(np.median(p_test))

y_hat_test = (p_test >= thr).astype(np.float32)
test_acc = float((y_hat_test == y_test_all).sum() / y_test_all.size)
test_mse = float(np.mean(test_losses))

print(f"Official TEST | MSE: {test_mse:.4f} | Acc: {test_acc:.4f} | thr: {thr:.3f}")
# Out:
# Official TEST | MSE: 0.1185 | Acc: 0.8472 | thr: 0.528

# %% [markdown]
# ## Visualisierung: Loss- und Accuracy-Kurven
# - Erstellt zwei Subplots:
#   - Train-/Val-Loss über die Epochen (MSE).
#   - Val-Accuracy über die Epochen (Skala 0–1).
# - Dient zur Diagnose von Lernverhalten, Over-/Underfitting und Stabilität.

# %%
# Nested Cross-Validation + Grid Search (nur network + NumPy/Pandas)
import numpy as np
from copy import deepcopy

# Hilfsfunktionen basierend auf vorhandenen network-Klassen
def build_model(input_dim, hidden_sizes):
    layers = []
    in_dim = input_dim
    for h in hidden_sizes:
        layers.append(LinearLayer(in_dim, h))
        layers.append(ReLU())
        in_dim = h
    layers.append(LinearLayer(in_dim, 1))
    return Model(*layers)

def make_loader(x, y, batch_size, shuffle):
    ds = Dataset(x, y)
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)

def train_one_config(X_tr, y_tr, X_val, y_val, config, seed=42):
    np.random.seed(seed)
    model = build_model(X_tr.shape[1], config['hidden_sizes'])
    loss_fn = MSELoss()
    optimizer = AdamWOptimizer(model, learning_rate=config['learning_rate'], weight_decay=config['weight_decay'])
    train_loader = make_loader(X_tr, y_tr, batch_size=config['batch_size'], shuffle=True)
    val_loader   = make_loader(X_val, y_val, batch_size=config['batch_size'], shuffle=False)
    for _ in range(config['num_epochs']):
        for xb, yb in train_loader:
            y_pred = model.forward(xb)
            loss = loss_fn.forward(y_pred, yb)
            grad = loss_fn.backward()
            model.backward(grad)
            optimizer.step()
    # Val loss
    val_losses = []
    for xb, yb in val_loader:
        yp = model.forward(xb)
        l  = loss_fn.forward(yp, yb)
        val_losses.append(l)
    return float(np.mean(val_losses)), model

def evaluate_test(model, X_te, y_te, batch_size):
    test_loader = make_loader(X_te, y_te, batch_size=batch_size, shuffle=False)
    loss_fn = MSELoss()
    losses = []
    correct = 0
    total = 0
    for xb, yb in test_loader:
        yp = model.forward(xb)
        l  = loss_fn.forward(yp, yb)
        losses.append(l)
        thr = float(np.median(yp))
        pred_bin = (yp >= thr).astype(np.float32)
        correct += (pred_bin == yb).sum()
        total   += yb.size
    return float(np.mean(losses)), float(correct/total)

# K-Fold Splitter (NumPy, ohne sklearn)
def kfold_indices(n_samples, k, seed=42, shuffle=True):
    rng = np.random.default_rng(seed)
    indices = np.arange(n_samples)
    if shuffle:
        rng.shuffle(indices)
    folds = np.array_split(indices, k)
    return folds

def get_train_val_from_folds(folds, val_fold_idx):
    val_idx = folds[val_fold_idx]
    train_idx = np.concatenate([folds[i] for i in range(len(folds)) if i != val_fold_idx])
    return train_idx, val_idx

# Grid Definition (klein halten wegen Laufzeit)
param_grid = {
    'hidden_sizes': [ (8, 8), (16, 8), (32, 16) ],
    'learning_rate': [ 0.001, 0.003 ],
    'weight_decay': [ 0.0, 1e-4, 1e-3 ],
    'batch_size': [ 16, 32 ],
    'num_epochs': [ 50 ]
}
grid_configs = []
for hs in param_grid['hidden_sizes']:
    for lr in param_grid['learning_rate']:
        for wd in param_grid['weight_decay']:
            for bs in param_grid['batch_size']:
                for ne in param_grid['num_epochs']:
                    grid_configs.append({
                        'hidden_sizes': hs,
                        'learning_rate': lr,
                        'weight_decay': wd,
                        'batch_size': bs,
                        'num_epochs': ne,
                    })

# Nested CV Parameter
k_outer = 5
k_inner = 3
print(f"Nested CV startet: outer k={k_outer}, inner k={k_inner}, grid size={len(grid_configs)}")
print(f"Erwartete Trainingsläufe: {k_outer} * {len(grid_configs)} * {k_inner} = {k_outer*len(grid_configs)*k_inner}")

# Nested CV wird auf dem TRAIN-Teil durchgeführt (offizielles Testset bleibt unangetastet).
X = X_train_full
y = y_train_full

N = X.shape[0]
outer_folds = kfold_indices(N, k_outer, seed=123, shuffle=True)

outer_results = []
for ofi in range(k_outer):
    # Outer split: hold-out Test = dieser Fold (innerhalb des TRAIN-Teils)
    test_idx = outer_folds[ofi]
    trainval_idx = np.concatenate([outer_folds[j] for j in range(k_outer) if j != ofi])
    X_trainval, y_trainval = X[trainval_idx], y[trainval_idx]
    X_test_cv,  y_test_cv  = X[test_idx],     y[test_idx]

    # Inner CV für Grid Search
    inner_folds = kfold_indices(X_trainval.shape[0], k_inner, seed=321+ofi, shuffle=True)
    cfg_to_score = []
    for cfg in grid_configs:
        inner_losses = []
        for ifi in range(k_inner):
            val_i_idx = inner_folds[ifi]
            train_i_idx = np.concatenate([inner_folds[j] for j in range(k_inner) if j != ifi])
            X_tr, y_tr = X_trainval[train_i_idx], y_trainval[train_i_idx]
            X_val_i, y_val_i = X_trainval[val_i_idx], y_trainval[val_i_idx]
            val_loss_i, _ = train_one_config(X_tr, y_tr, X_val_i, y_val_i, cfg, seed=42+ifi)
            inner_losses.append(val_loss_i)
        cfg_to_score.append((cfg, float(np.mean(inner_losses))))
    # beste Konfiguration nach mittlerem inner Val-Loss
    cfg_to_score.sort(key=lambda x: x[1])
    best_cfg, best_inner_loss = cfg_to_score[0]

    # Retrain auf vollständigem Train+Val des Outer-Folds und Eval auf Outer-Test
    _, best_model = train_one_config(X_trainval, y_trainval, X_test_cv, y_test_cv, best_cfg, seed=999)
    test_loss, test_acc = evaluate_test(best_model, X_test_cv, y_test_cv, batch_size=best_cfg['batch_size'])
    print(f"[Outer {ofi+1}/{k_outer}] Best cfg={best_cfg} | inner mean ValLoss={best_inner_loss:.4f} | TestLoss={test_loss:.4f} | TestAcc={test_acc:.4f}")
    outer_results.append({
        'outer_fold': ofi,
        'best_cfg': best_cfg,
        'inner_mean_val_loss': best_inner_loss,
        'test_loss': test_loss,
        'test_acc': test_acc,
    })

# Zusammenfassung
mean_test_loss = float(np.mean([r['test_loss'] for r in outer_results]))
mean_test_acc  = float(np.mean([r['test_acc']  for r in outer_results]))
print("\n=== Gesamtergebnisse über Outer-Folds ===")
print(f"Mean Test Loss: {mean_test_loss:.4f}")
print(f"Mean Test Acc : {mean_test_acc:.4f}")
# Out:
# Nested CV startet: outer k=5, inner k=3, grid size=36
# Erwartete Trainingsläufe: 5 * 36 * 3 = 540
# [Outer 1/5] Best cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 32, 'num_epochs': 50} | inner mean ValLoss=0.2793 | TestLoss=0.1356 | TestAcc=0.5588
# [Outer 2/5] Best cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.003, 'weight_decay': 0.0001, 'batch_size': 16, 'num_epochs': 50} | inner mean ValLoss=0.2097 | TestLoss=0.1518 | TestAcc=0.7941
# [Outer 3/5] Best cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.003, 'weight_decay': 0.0001, 'batch_size': 32, 'num_epochs': 50} | inner mean ValLoss=0.2548 | TestLoss=0.2076 | TestAcc=0.7059
# [Outer 4/5] Best cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.003, 'weight_decay': 0.001, 'batch_size': 16, 'num_epochs': 50} | inner mean ValLoss=0.2163 | TestLoss=0.1234 | TestAcc=0.7941
# [Outer 5/5] Best cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 16, 'num_epochs': 50} | inner mean ValLoss=0.2509 | TestLoss=0.1679 | TestAcc=0.6364
#
# === Gesamtergebnisse über Outer-Folds ===
# Mean Test Loss: 0.1572
# Mean Test Acc : 0.6979

# %% [markdown]
# ## Nested Cross-Validation mit Grid Search
# Dieser Abschnitt führt eine verschachtelte Cross-Validation (Nested CV) durch, um Hyperparameter robust zu wählen und anschließend die Generalisierungsleistung zu messen.
#
# - Outer K-Folds: Jeder Fold dient einmal als unabhängiges Test-Set. Die übrigen Daten bilden das Train+Val-Set.
# - Inner K-Folds: Für jede Hyperparameter-Kombination wird eine K-fache Validierung innerhalb des Train+Val-Sets durchgeführt. Der mittlere Validierungs-Loss über die inneren Folds dient als Gütemaß.
# - Auswahl: Die Konfiguration mit dem kleinsten mittleren inneren Val-Loss wird pro Outer-Fold gewählt.
# - Retrain + Test: Mit der gewählten Konfiguration wird auf dem gesamten Train+Val des Outer-Folds trainiert und auf dem gehaltenen Test-Set evaluiert (Loss + Accuracy).
#
# Wichtige Punkte:
# - Es werden ausschließlich die vorhandenen `network`-Bausteine verwendet (`Model`, `LinearLayer`, `ReLU`, `MSELoss`, `AdamWOptimizer`, `Dataset`, `DataLoader`).
# - Für die Accuracy wird ein datengetriebener Schwellenwert verwendet (Median der Predictions je Auswertung), da die letzte Schicht linear ist und keine Sigmoid-Aktivierung nutzt.
# - Die erwartete Anzahl Trainingsläufe ist `k_outer * grid_size * k_inner`, hier bewusst klein gehalten, um Laufzeit zu kontrollieren.

# %%
# Visualisierung der Grid-Resultate und Outer-Fold-Ergebnisse
import numpy as np
import matplotlib.pyplot as plt

# Erwartet: Variablen aus der Nested-CV-Zelle
# - grid_configs: Liste aller getesteten Konfigurationen
# - outer_results: Liste mit Einträgen {'outer_fold', 'best_cfg', 'inner_mean_val_loss', 'test_loss', 'test_acc'}

# 1) Balkendiagramm: Test-Loss und Test-Accuracy je Outer-Fold
fold_ids   = [r['outer_fold']+1 for r in outer_results]
test_losses = [r['test_loss'] for r in outer_results]
test_accs   = [r['test_acc']  for r in outer_results]

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.bar(fold_ids, test_losses, color='tab:blue')
plt.xlabel('Outer Fold')
plt.ylabel('Test Loss (MSE)')
plt.title('Test Loss je Outer-Fold')
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
plt.bar(fold_ids, test_accs, color='tab:green')
plt.xlabel('Outer Fold')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy je Outer-Fold')
plt.ylim(0.0, 1.0)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 2) Auswahlhäufigkeit der besten Konfigurationen: Heatmaps pro hidden_sizes
# Wir stellen die Häufigkeit dar, mit der (learning_rate, weight_decay)
# pro hidden_sizes als beste Konfiguration gewählt wurde.
# Das ist eine kompakte graphische Repräsentation des Grids via Auswahlfrequenz.

# Extrahiere eindeutige Werte
hidden_sizes_list = sorted(list({cfg['hidden_sizes'] for cfg in grid_configs}))
lr_list           = sorted(list({cfg['learning_rate'] for cfg in grid_configs}))
wd_list           = sorted(list({cfg['weight_decay'] for cfg in grid_configs}))

# Zähle Best-Selections
from collections import defaultdict
freq = defaultdict(int)
for r in outer_results:
    cfg = r['best_cfg']
    key = (tuple(cfg['hidden_sizes']), cfg['learning_rate'], cfg['weight_decay'])
    freq[key] += 1

# Erzeuge Heatmaps: Zeilen=learning_rate, Spalten=weight_decay; pro hidden_sizes ein Subplot
n_rows = len(hidden_sizes_list)
fig, axes = plt.subplots(n_rows, 1, figsize=(8, 4*n_rows), squeeze=False)

for i, hs in enumerate(hidden_sizes_list):
    mat = np.zeros((len(lr_list), len(wd_list)), dtype=float)
    for r_i, lr in enumerate(lr_list):
        for c_i, wd in enumerate(wd_list):
            mat[r_i, c_i] = freq.get((hs, lr, wd), 0)
    ax = axes[i, 0]
    im = ax.imshow(mat, cmap='Blues', aspect='auto')
    ax.set_title(f'Auswahlhäufigkeit best cfg für hidden_sizes={hs}')
    ax.set_xticks(np.arange(len(wd_list)))
    ax.set_xticklabels([str(wd) for wd in wd_list])
    ax.set_xlabel('weight_decay')
    ax.set_yticks(np.arange(len(lr_list)))
    ax.set_yticklabels([str(lr) for lr in lr_list])
    ax.set_ylabel('learning_rate')
    for r_i in range(len(lr_list)):
        for c_i in range(len(wd_list)):
            ax.text(c_i, r_i, f"{int(mat[r_i, c_i])}", ha='center', va='center', color='black')
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# 3) Tabelle der besten Konfigurationen je Outer-Fold (als Textausgabe)
print('\nBeste Konfiguration je Outer-Fold:')
for r in outer_results:
    print(f"Fold {r['outer_fold']+1}: cfg={r['best_cfg']} | TestLoss={r['test_loss']:.4f} | TestAcc={r['test_acc']:.4f}")
# Out:
# Beste Konfiguration je Outer-Fold:
# Fold 1: cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 32, 'num_epochs': 50} | TestLoss=0.1356 | TestAcc=0.5588
# Fold 2: cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.003, 'weight_decay': 0.0001, 'batch_size': 16, 'num_epochs': 50} | TestLoss=0.1518 | TestAcc=0.7941
# Fold 3: cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.003, 'weight_decay': 0.0001, 'batch_size': 32, 'num_epochs': 50} | TestLoss=0.2076 | TestAcc=0.7059
# Fold 4: cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.003, 'weight_decay': 0.001, 'batch_size': 16, 'num_epochs': 50} | TestLoss=0.1234 | TestAcc=0.7941
# Fold 5: cfg={'hidden_sizes': (16, 8), 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 16, 'num_epochs': 50} | TestLoss=0.1679 | TestAcc=0.6364

# %% [markdown]
# ## Visualisierung der Grid- und Fold-Ergebnisse
# Diese Zelle fasst die Resultate der Nested-CV grafisch zusammen.
#
# - Balkendiagramme: Zeigen pro Outer-Fold den Test-Loss (MSE) und die Test-Accuracy. Damit wird die Varianz über verschiedene Test-Splits sichtbar.
# - Heatmaps: Visualisieren die Auswahlhäufigkeit der besten Konfigurationen für jedes `hidden_sizes`-Setting. Achsen sind `learning_rate` (Zeilen) und `weight_decay` (Spalten); der Zellenwert gibt an, wie oft die Kombination als beste Konfiguration gewählt wurde.
# - Tabelle: Listet pro Outer-Fold die gefundene beste Konfiguration und deren Testkennzahlen als Text aus.
#
# Hinweise:
# - Die Heatmaps sind eine kompakte Repräsentation des Parameter-Grids; sie zeigen, welche Bereiche des Grids häufiger vorn liegen.
# - Mit größeren Grids können weitere Dimensionen (z. B. `batch_size`, `num_epochs`) separat visualisiert werden (z. B. zusätzliche Subplots).

# %%
# Accuracy-Kurve über Epochen für die beste Konfiguration (aus Nested CV)
import numpy as np
import matplotlib.pyplot as plt

# Wir trainieren die best_cfg erneut und zeichnen Val-Accuracy je Epoche auf.
# Nutzung ausschließlich der vorhandenen network-Klassen.

def train_with_acc_history(X_tr, y_tr, X_val, y_val, cfg, seed=123):
    np.random.seed(seed)
    model = build_model(X_tr.shape[1], cfg['hidden_sizes'])
    loss_fn = MSELoss()
    optimizer = AdamWOptimizer(model, learning_rate=cfg['learning_rate'], weight_decay=cfg['weight_decay'])
    train_loader = make_loader(X_tr, y_tr, batch_size=cfg['batch_size'], shuffle=True)
    val_loader   = make_loader(X_val, y_val, batch_size=cfg['batch_size'], shuffle=False)
    train_loss_hist = []
    val_loss_hist   = []
    val_acc_hist    = []
    for _ in range(cfg['num_epochs']):
        # Train
        train_losses = []
        for xb, yb in train_loader:
            yp = model.forward(xb)
            l  = loss_fn.forward(yp, yb)
            g  = loss_fn.backward()
            model.backward(g)
            optimizer.step()
            train_losses.append(l)
        # Validate
        val_losses = []
        preds_all = []
        ys_all    = []
        for xb, yb in val_loader:
            yp = model.forward(xb)
            l  = loss_fn.forward(yp, yb)
            val_losses.append(l)
            preds_all.append(yp)
            ys_all.append(yb)
        mean_train = float(np.mean(train_losses))
        mean_val   = float(np.mean(val_losses))
        p = np.concatenate(preds_all, axis=0)
        y_true = np.concatenate(ys_all, axis=0)
        thr = float(np.median(p))
        pred_bin = (p >= thr).astype(np.float32)
        acc = float((pred_bin == y_true).sum() / y_true.size)
        train_loss_hist.append(mean_train)
        val_loss_hist.append(mean_val)
        val_acc_hist.append(acc)
    return {
        'model': model,
        'train_loss_history': train_loss_hist,
        'val_loss_history': val_loss_hist,
        'val_acc_history': val_acc_hist,
    }

# Safeguard: Falls best_cfg nicht existiert (Zelle nicht ausgeführt)
try:
    hist_run = train_with_acc_history(
        X_trainval, y_trainval, X_test, y_test, best_cfg, seed=2025
    )
    epochs = np.arange(1, len(hist_run['train_loss_history']) + 1)
    plt.figure(figsize=(12, 5))
    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, hist_run['train_loss_history'], label='Train Loss')
    plt.plot(epochs, hist_run['val_loss_history'], label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.title('Train & Val Loss (best cfg)')
    plt.legend()
    plt.grid(alpha=0.3)
    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, hist_run['val_acc_history'], color='tab:green', label='Val Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Val Accuracy (best cfg)')
    plt.ylim(0.0, 1.0)
    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()
except NameError:
    print('Bitte zuerst die Nested-CV-Zelle ausführen, damit best_cfg/X_trainval/y_trainval/X_test/y_test verfügbar sind.')

# %% [markdown]
# ## Accuracy-Kurve für die beste Konfiguration
# Diese Zelle trainiert die aus der Nested CV ermittelte `best_cfg` erneut und protokolliert pro Epoche:
# - Train-Loss (MSE)
# - Val-Loss (MSE)
# - Val-Accuracy (binär, mit Median-Threshold über die Val-Predictions der jeweiligen Epoche)
#
# Warum Median-Threshold?
# - Da der letzte Layer linear ist (ohne Sigmoid), liegen die Roh-Predictions nicht notwendigerweise in [0, 1]. Der Median als dynamischer Schwellenwert teilt die Vorhersagen pro Epoche robust in zwei Klassen, ohne zusätzliche Aktivierungsfunktion.
#
# Was der Plot zeigt:
# - Linke Seite: Train/Val-Loss über die Epochen – Lernfortschritt und potenzielles Over-/Underfitting.
# - Rechte Seite: Val-Accuracy – Klassifikationsgüte über die Zeit.
#
# Falls `best_cfg` oder die benötigten Datensplits (`X_trainval`, `y_trainval`, `X_test`, `y_test`) nicht verfügbar sind, bitte zuerst die Nested-CV-Zelle ausführen.

# %%
# Plots für MONK-Datensätze mit Guidelines (BW, große Fonts)
import numpy as np
import matplotlib.pyplot as plt

# Hilfsfunktion: Genauigkeit über Epochen (Median-Threshold)
def accuracy_median_threshold(y_true_epoch_list, y_pred_epoch_list):
    accs = []
    for t, p in zip(y_true_epoch_list, y_pred_epoch_list):
        thr = np.median(p)
        y_hat = (p >= thr).astype(np.float32)
        correct = (y_hat == t).astype(np.float32)
        accs.append(float(np.mean(correct)))
    return np.array(accs)

# Plot-Funktion mit Guidelines (BW lesbar, große Fonts)
def plot_curves_guideline(train_mse, val_mse, train_acc=None, val_acc=None, title_prefix='MONK'):
    plt.rcParams.update({
        'font.size': 14,
        'axes.labelsize': 16,
        'axes.titlesize': 18,
        'legend.fontsize': 14,
        'xtick.labelsize': 13,
        'ytick.labelsize': 13,
    })
    epochs = np.arange(1, len(train_mse)+1)
    fig = plt.figure(figsize=(12,5))
    # MSE links
    ax1 = fig.add_subplot(1,2,1)
    ax1.plot(epochs, train_mse, linestyle='-', linewidth=2.5, label='Training MSE')
    ax1.plot(epochs, val_mse,   linestyle='--', linewidth=2.5, label='Test MSE')
    ax1.set_title('MSE')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('MSE')
    ax1.grid(alpha=0.4)
    ax1.legend(loc='best')
    # Accuracy rechts (auch wenn nur val_acc vorhanden)
    ax2 = fig.add_subplot(1,2,2)
    lines_plotted = False
    if train_acc is not None:
        ax2.plot(epochs, train_acc, linestyle='-',  linewidth=2.5, label='Training Accuracy')
        lines_plotted = True
    if val_acc is not None:
        ax2.plot(epochs, val_acc,   linestyle='--', linewidth=2.5, label='Test Accuracy')
        lines_plotted = True
    ax2.set_title('Accuracy %')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.grid(alpha=0.4)
    if lines_plotted:
        ax2.legend(loc='best')
    plt.tight_layout()
    plt.show()

# Automatischer Fallback: nutze vorhandene Historien aus den Trainingszellen
# train_loss_history, val_loss_history, val_acc_history
try:
    train_mse_fallback = np.array(train_loss_history)
    val_mse_fallback   = np.array(val_loss_history)
    val_acc_fallback   = np.array(val_acc_history) if 'val_acc_history' in globals() else None
    # Wenn nur val_acc existiert, zeichnen wir zumindest diese
    plot_curves_guideline(train_mse_fallback, val_mse_fallback, None, val_acc_fallback, title_prefix='MONK')
except Exception as e:
    print('Plot-Fallback fehlgeschlagen:', e)
    print('Bitte stelle sicher, dass train_loss_history/val_loss_history (und optional val_acc_history) definiert sind.')

# Optional: Vollversion für MONK1/2/3 mit detaillierten Listen, falls vorhanden
try:
    # MONK 1
    train_mse_1 = np.array(train_mse_monks[0])
    val_mse_1   = np.array(val_mse_monks[0])
    train_acc_1 = accuracy_median_threshold(train_trues_monks[0], train_preds_monks[0])
    val_acc_1   = accuracy_median_threshold(val_trues_monks[0],   val_preds_monks[0])
    plot_curves_guideline(train_mse_1, val_mse_1, train_acc_1, val_acc_1, title_prefix='MONK 1')
    # MONK 2
    train_mse_2 = np.array(train_mse_monks[1])
    val_mse_2   = np.array(val_mse_monks[1])
    train_acc_2 = accuracy_median_threshold(train_trues_monks[1], train_preds_monks[1])
    val_acc_2   = accuracy_median_threshold(val_trues_monks[1],   val_preds_monks[1])
    plot_curves_guideline(train_mse_2, val_mse_2, train_acc_2, val_acc_2, title_prefix='MONK 2')
    # MONK 3
    train_mse_3 = np.array(train_mse_monks[2])
    val_mse_3   = np.array(val_mse_monks[2])
    train_acc_3 = accuracy_median_threshold(train_trues_monks[2], train_preds_monks[2])
    val_acc_3   = accuracy_median_threshold(val_trues_monks[2],   val_preds_monks[2])
    plot_curves_guideline(train_mse_3, val_mse_3, train_acc_3, val_acc_3, title_prefix='MONK 3')
except NameError:
    # Wenn die detaillierten MONK-Listen nicht existieren, ist das okay – Fallback oben genügt.
    pass

# %%
# ---- Run the same training pipeline for all 3 problems (optional) ----
# This assumes the training loop below uses X_train/y_train/X_val/y_val/X_test/y_test from the current problem.
# If your training loop is wrapped into a function already, call that here.
# Otherwise, the easiest is: set PROBLEM_ID=1 and RUN_ALL=False, run the notebook once;
# then repeat for PROBLEM_ID=2 and 3.

# Below is a lightweight example that reuses your build_model() from the nested-CV section (if present).
# If you don't have build_model() earlier, ignore this cell.

if RUN_ALL and "build_model" in globals():
    results = {}
    for pid in [1,2,3]:
        PROBLEM_ID = pid
        X_train_full, y_train_full, X_test, y_test, feature_names = load_monk(PROBLEM_ID)

        rng = np.random.default_rng(42)
        idx = np.arange(X_train_full.shape[0])
        rng.shuffle(idx)
        n_val = int(0.2 * len(idx))
        val_idx, train_idx = idx[:n_val], idx[n_val:]

        X_train, y_train = X_train_full[train_idx], y_train_full[train_idx]
        X_val,   y_val   = X_train_full[val_idx],   y_train_full[val_idx]

        model = build_model(X_train.shape[1], hidden1=16, hidden2=8)  # adapt args to your build_model signature
        # TODO: plug in your training loop here, then evaluate on X_test/y_test.
        results[pid] = {"train_n": len(train_idx), "val_n": len(val_idx), "test_n": X_test.shape[0]}

    print(results)
